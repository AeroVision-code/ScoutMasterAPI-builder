# %% [markdown]
# ## Fields

# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt

# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath(".."))
from API_ScoutMaster_V2 import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
project_id = os.getenv('SM_PROJECT_ID')

# Scoutmaster API - Init
SM_API = ScoutMasterAPI()
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# ✅ Successfully authenticated ScoutMaster API

# %%
output_folder = "../data/output/"

# %%
SM_API.output_format = 'df'
df_layer_types = SM_API.layers_types(project_id=project_id)
df_layer_types
# Out:
#                                      id       name    type fs_code  \
# 0  13be9851-8133-4b7c-b9ea-1a38683224ba        DSM   index     ahn
# 1  d7ba4f2e-38b9-4fe2-a598-d552b8327c0b     Hoogte   index     ahn
# 2  0a0e0317-8dad-4118-8150-f7a29732cd65   Scouting  vector      P6
# 3  0685e79a-d5ca-43f8-a634-6068bdbacfab   Biomassa   index      P2
# 4  502ff6f2-d14a-4e4d-a54c-ba14b1f84387   Stikstof   index      P5
# 5  9fa20d5b-e46f-424f-b16f-0200bea8c510   Bijgroei   index      P4
# 6  adbd41e6-6442-4ab7-961e-41e46556e118  Prestatie   index     P14
#
#   abbreviation                                       layer_source  \
# 0          DSM  {'id': '7dfe647f-3caa-4146-8ef3-dcfb5b87a634',...
# 1          DTM  {'id': '7dfe647f-3caa-4146-8ef3-dcfb5b87a634',...
# 2        SCOUT  {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 3         WDVI  {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 4       CI-red  {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 5   Add-growth  {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 6         Perf  {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
#
#                                        preview_image
# 0  https://bioscope-products.s3.eu-central-1.amaz...
# 1  https://bioscope-products.s3.eu-central-1.amaz...
# 2  https://bioscope-products.s3.eu-central-1.amaz...
# 3  https://bioscope-products.s3.eu-central-1.amaz...
# 4  https://bioscope-products.s3.eu-central-1.amaz...
# 5  https://bioscope-products.s3.eu-central-1.amaz...
# 6  https://bioscope-products.s3.eu-central-1.amaz...

# %%
from IPython.display import Image, HTML, display

def show_layer_previews(df, limit=10):
    rows = []
    for i, row in df.head(limit).iterrows():
        rows.append(f"""
        <div style="display:inline-block; margin:10px; text-align:center;">
            <img src="{row['preview_image']}" width="150"><br>
            <b>{row['name']}</b><br>
            <small>{row['abbreviation']}</small>
        </div>
        """)
    display(HTML("".join(rows)))

show_layer_previews(df_layer_types)
# Out:
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20250916%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20250916T075052Z&X-Amz-Expires=3600&X-Amz-Signature=55dbbf2738c09fff1b2b94844477c9cb37af94ed22f2d27e0f64a9cc3062be39&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>DSM</b><br>
#             <small>DSM</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20250916%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20250916T075052Z&X-Amz-Expires=3600&X-Amz-Signature=55dbbf2738c09fff1b2b94844477c9cb37af94ed22f2d27e0f64a9cc3062be39&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Hoogte</b><br>
#             <small>DTM</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ndvi.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20250916%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20250916T075052Z&X-Amz-Expires=3600&X-Amz-Signature=3d1943fb631be1a591623d664ad14ff55416551c0f666a93df75607c3de92a80&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Scouting</b><br>
#             <small>SCOUT</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/PLanet_WDVI.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20250916%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20250916T075052Z&X-Amz-Expires=3600&X-Amz-Signature=9c79c584f11d1e9ed5e197a36865ed44ed216965f398251fe48cd078f0f39b91&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Biomassa</b><br>
#             <small>WDVI</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_CI-Red.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20250916%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20250916T075052Z&X-Amz-Expires=3600&X-Amz-Signature=8f90d164ce6b8e14a93a697755419f9598765a5f0d0253a392741027487c80a5&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Stikstof</b><br>
#             <small>CI-red</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_AddGrowth.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20250916%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20250916T075052Z&X-Amz-Expires=3600&X-Amz-Signature=79dda089a8cb9c6cb3433b1708f0f2a6c7a4e5c275336864ce545503440dec1f&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Bijgroei</b><br>
#             <small>Add-growth</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/planet_performance.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20250916%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20250916T075052Z&X-Amz-Expires=3600&X-Amz-Signature=e8835717afcd48a6bea3a4dc7ba5b8117fddcc9db0c8925d482f7a046e5cd831&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Prestatie</b><br>
#             <small>Perf</small>
#         </div>
