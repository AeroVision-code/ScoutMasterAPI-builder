# %% [markdown]
# ## Cultivations

# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import folium
import pandas as pd
import geopandas as gpd

# Load environment variables from .env file
load_dotenv()

# import the API builder
from scoutmasterapi_builder.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
project_id = os.getenv('SM_PROJECT_ID')
dev = os.getenv("DEV")

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(dev, version="v3")
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# Initialized ScoutMaster API with host: https://dev-api.scoutmaster.nl/v3/
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://dev-api.scoutmaster.nl/v3/

# %%
output_folder = "../../data/output/"

# %%
SM_API.output_format = 'df'
df_cultivations = SM_API.cultivations(project_id=project_id)
df_cultivations
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
cultivation_data = {
  "crop_code": 1080101,
  "crop_variety_code": 20596,
  "plant_date": "2022-04-15",
  "harvest_date": "2022-09-30"
}

SM_API.cultivations_create(field_id="39507fbd-6f0e-49e5-bdb2-f36d964cffa1", cultivation_data=cultivation_data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\hoek008\miniforge3\envs\geo311\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     977 try:
# --> 978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\hoek008\miniforge3\envs\geo311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\hoek008\miniforge3\envs\geo311\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\hoek008\miniforge3\envs\geo311\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\hoek008\miniforge3\envs\geo311\Lib\site-packages\scoutmasterapi_builder\base.py:95, in BaseAPI._post(self, endpoint, payload, files)
#      94 try:
# ---> 95     response_json = response.json()
#      96 except ValueError:
#      97     # Non-JSON response
#
# File c:\Users\hoek008\miniforge3\envs\geo311\Lib\site-packages\requests\models.py:982, in Response.json(self, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 982     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 8
#       1 cultivation_data = {
#       2   "crop_code": 1080101,
#       3   "crop_variety_code": 20596,
#       4   "plant_date": "2022-04-15",
#       5   "harvest_date": "2022-09-30"
#       6 }
# ----> 8 SM_API.cultivations_create(field_id="39507fbd-6f0e-49e5-bdb2-f36d964cffa1", cultivation_data=cultivation_data)
#
# File c:\Users\hoek008\miniforge3\envs\geo311\Lib\site-packages\scoutmasterapi_builder\cultivations.py:27, in Cultivations.cultivations_create(self, field_id, cultivation_data)
#      25 def cultivations_create(self, field_id, cultivation_data):
#      26     endpoint = f"fields/{field_id}/calendar"
# ---> 27     data = self._post(endpoint, cultivation_data)
#      28     return self._format_output(data)
#
# File c:\Users\hoek008\miniforge3\envs\geo311\Lib\site-packages\scoutmasterapi_builder\base.py:98, in BaseAPI._post(self, endpoint, payload, files)
#      95         response_json = response.json()
#      96     except ValueError:
#      97         # Non-JSON response
# ---> 98         raise Exception(
#      99             f"POST request to {endpoint} did not return valid JSON. "
#     100             f"Response content: {response.text}"
#     101         )
#     102 else:
#     103     response_json = {}
#
# Exception: POST request to fields/39507fbd-6f0e-49e5-bdb2-f36d964cffa1/calendar did not return valid JSON. Response content: <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8">
# <title>Error</title>
# </head>
# <body>
# <pre>Cannot POST /v3/fields/39507fbd-6f0e-49e5-bdb2-f36d964cffa1/calendar</pre>
# </body>
# </html>
