# %% [markdown]
# ## Users

# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import folium
import pandas as pd
import geopandas as gpd

# Load environment variables from .env file
load_dotenv()

# import the API builder
from scoutmasterapi_builder.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
project_id = os.getenv('SM_PROJECT_ID')
dev = os.getenv("DEV")

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(dev)
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# Initialized ScoutMaster API with host: https://api.scoutmaster.nl/v2/
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://api.scoutmaster.nl/v2/

# %%
output_folder = "../../data/output/"

# %%
SM_API.output_format = 'df'
df_users = SM_API.users(project_id=project_id)
df_users
# Out:
#                                      id                               user_id  \
# 0  20b1ec07-38b8-4623-a054-e5dd8f731bfa  732438c2-a0e1-70b9-2acb-588cee45d472
# 1  04e5e413-d499-4978-ae32-7dfb615ad588  033448b2-0071-700f-ba76-ac4f39e1c81d
# 2  042020c6-f891-4fe6-8167-c161db3c1dd9  33e4d892-3081-7076-9b3c-a0ca1d95b937
# 3  59fc8049-79b0-44f9-8a35-16fc3f5f2c18  7384c882-7081-7022-8fd2-0da66f49772b
# 4  42909831-25a8-4a39-b93f-4960a3ab4a52  d3c4a822-7051-7060-b45c-06c6b7bffa09
# 5  e16ef54c-9b8e-40e5-8acc-fff412b3d60e  4324f8f2-6041-7008-9391-9fd2df2d935a
#
#                              project_id user_role            username  \
# 0  7da1d70e-9e46-402c-a454-2d9332ecdc31     owner            agritip1
# 1  7da1d70e-9e46-402c-a454-2d9332ecdc31     owner  rinusvijftigschild
# 2  7da1d70e-9e46-402c-a454-2d9332ecdc31     owner       wessel_eshuis
# 3  7da1d70e-9e46-402c-a454-2d9332ecdc31    member                 jan
# 4  7da1d70e-9e46-402c-a454-2d9332ecdc31    member           erikjan22
# 5  7da1d70e-9e46-402c-a454-2d9332ecdc31    member             gubbels
#
#                   name                              email  email_verified  \
# 0              Agritip                 agritip@agritip.nl            True
# 1  rinus vijftigschild  rinus.vijftigschild@aerovision.nl            True
# 2        Wessel Eshuis        wessel.eshuis@aerovision.nl            True
# 3           jan wijnen            jan.wijnen@soil-data.nl            True
# 4         Erik Bootsma         erik.bootsma@aerovision.nl            True
# 5                  A.W                info@gubbelsagro.nl            True
#
#    phone_number_verified     status                created_at  \
# 0                  False  CONFIRMED  2025-11-19T12:50:38.801Z
# 1                   True  CONFIRMED  2025-07-23T13:53:18.225Z
# 2                  False  CONFIRMED  2025-08-15T08:17:42.733Z
# 3                  False  CONFIRMED  2025-11-06T10:00:22.235Z
# 4                  False  CONFIRMED  2025-07-30T14:03:41.517Z
# 5                  False  CONFIRMED  2026-02-14T10:10:24.022Z
#
#               last_modified  enabled  phone_number
# 0  2025-11-19T12:54:52.137Z     True           NaN
# 1  2025-07-23T14:05:22.862Z     True  +31621694192
# 2  2026-01-08T14:12:29.916Z     True           NaN
# 3  2025-11-06T10:00:58.806Z     True           NaN
# 4  2025-07-30T14:03:53.457Z     True           NaN
# 5  2026-03-06T09:33:39.068Z     True           NaN
