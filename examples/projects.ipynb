# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import folium

# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath(".."))
from API_ScoutMaster_V2 import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')

# Scoutmaster API - Init
SM_API = ScoutMasterAPI()
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# ✅ Successfully authenticated ScoutMaster API

# %%
projects = SM_API.get_projects()
projects
# Out:
#                                      id                 name abbreviation  \
# 0  04d28e3a-c0af-4def-9cae-e452cee217f0                 TOIS           To
# 1  2110f1eb-25fd-439c-aafb-de46e50824e5             Broccoli           Br
# 2  44e39889-cb62-4ac5-8f15-3a9628f33a3e  De Enk Groen & Golf           En
# 3  6d3359ee-2988-4b23-b35b-14391e0eaa5f   04/06/2025 project           Pr
# 4  a344fa5f-0b42-4ed4-afe5-f85126a1737a            SOIL-Data           So
# 5  c52cc8b0-fd2e-4d7b-bc73-9623f8f212ae        Abaco project           Ab
# 6  db21b65c-88b0-401f-b7e2-700737e1717a    ChicoGrow project           Ch
# 7  ff9548db-3e82-4f59-9995-fdfb010ebb57                 SQAT           Sq
#
#                                            logo_path
# 0  https://bioscope-products.s3.eu-central-1.amaz...
# 1                                               None
# 2  https://bioscope-products.s3.eu-central-1.amaz...
# 3                                               None
# 4  https://bioscope-products.s3.eu-central-1.amaz...
# 5  https://bioscope-products.s3.eu-central-1.amaz...
# 6  https://bioscope-products.s3.eu-central-1.amaz...
# 7                                               None
