# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import folium

# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath("../../"))
from scoutmaster.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
user_id = os.getenv("SM_USER_ID")
dev = False

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(dev)
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://dev-api.scoutmaster.nl/v2/

# %%
user_id = "033448b2-0071-700f-ba76-ac4f39e1c81d"
name = "test latest"
abbreviation = "te"

# %%
project = SM_API.project_create(user_id, name, abbreviation)
project_id = project["id"]
# Out:
# {'id': 'a8cfb086-473a-47e7-b698-0895eba9d18b', 'name': 'test', 'abbreviation': 'te', 'logo_id': None, 'created_at': '2025-12-09T22:01:32.229Z', 'deleted_at': None, 'updated_at': '2025-12-09T22:01:32.229Z'}

# %%
print(client_id)
# Out:
# 50qk27r77t7njdbofgfafttguo

# %%
path_logo =  "./p2.png"
data = SM_API.project_upload_logo(project_id, path_logo)
# Out:
# {'upload_url': 'https://bioscope-products-dev.s3.eu-central-1.amazonaws.com/projects/logo/new/a8cfb086-473a-47e7-b698-0895eba9d18b.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20251209%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251209T220132Z&X-Amz-Expires=300&X-Amz-Signature=d7ab1d208958c5f5620f595ff7ed79839a4d6830edf405d7cb608784810535c4&X-Amz-SignedHeaders=host&x-amz-checksum-crc32=AAAAAA%3D%3D&x-amz-sdk-checksum-algorithm=CRC32&x-id=PutObject', 'file_key': 'projects/logo/new/a8cfb086-473a-47e7-b698-0895eba9d18b.png', 'public_url': 'https://bioscope-products-dev.s3.eu-central-1.amazonaws.com/projects/logo/new/a8cfb086-473a-47e7-b698-0895eba9d18b.png'}
# Logo uploaded successfully!

# %%
data
# Out:
# {'project_id': 'a8cfb086-473a-47e7-b698-0895eba9d18b',
#  'file_key': 'projects/logo/new/a8cfb086-473a-47e7-b698-0895eba9d18b.png',
#  'public_url': 'https://bioscope-products-dev.s3.eu-central-1.amazonaws.com/projects/logo/new/a8cfb086-473a-47e7-b698-0895eba9d18b.png'}
