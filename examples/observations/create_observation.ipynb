# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import folium
import pandas as pd
import geopandas as gpd

# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath("../../"))
from scoutmaster.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
project_id = os.getenv('SM_PROJECT_ID')
dev = os.getenv("DEV")

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(dev)
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://dev-api.scoutmaster.nl/v2/

# %%
obs = {
    "user_id": "033448b2-0071-700f-ba76-ac4f39e1c81d",
    "acquired_at": "2025-11-25T15:30:00Z",
    "geometry": {
        "type": "Point",
        "coordinates": [102, 0.5]
    },
    "reference_code": "OBS-10"
}

df_obs = SM_API.observations_create(project_id="5f88d0d3-e4fc-482d-8981-b3532fa7e2c7", obs_data=obs)

print("OBS_id:", obs_id)
# Out:
# <Response [500]>
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 11
#       1 obs = {
#       2     "user_id": "033448b2-0071-700f-ba76-ac4f39e1c81d",
#       3     "acquired_at": "2025-11-25T15:30:00Z",
#    (...)      8     "reference_code": "OBS-10"
#       9 }
# ---> 11 df_obs = SM_API.observations_create(project_id="5f88d0d3-e4fc-482d-8981-b3532fa7e2c7", obs_data=obs)
#      12 obs_id = df_obs["id"]
#      13 print("OBS_id:", obs_id)
#
# File c:\AeroVision-repo\ScoutMasterAPI-builder\scoutmaster\observations.py:57, in Observations.observations_create(self, project_id, obs_data)
#      50         return self._format_output(data["data"][0])
#      51         # return (
#      52         #     pd.DataFrame([response_json])
#      53         #     if self.output_format == "df"
#      54         #     else response_json
#      55         # )
#      56     else:
# ---> 57         raise Exception(
#      58             f"Failed to create observation: "
#      59             f"{response.status_code} {response.text}"
#      60         )
#      62 except requests.exceptions.RequestException as e:
#      63     raise Exception(f"Request failed: {e}")
#
# Exception: Failed to create observation: 500 {"message":"duplicate key value violates unique constraint \"scoutmaster_observation_unique\""}

# %%
values =  {
        "parameter_id": 1,
        "value": 23.5
}

# %%
obs_id = "46f83eeb-d28d-4080-8150-0b49a49be320"
SM_API.observations_values_create(obs_id, values)
# Out:
# {'id': 906,
#  'value': 23.5,
#  'observation_id': '46f83eeb-d28d-4080-8150-0b49a49be320',
#  'observation_parameter_id': 1,
#  'operator_id': 1}
