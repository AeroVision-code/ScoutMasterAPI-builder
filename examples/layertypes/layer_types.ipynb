# %% [markdown]
# ## Layer types

# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt

# Load environment variables from .env file
load_dotenv()

# import the API builder
from scoutmasterapi_builder.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
project_id = os.getenv('SM_PROJECT_ID')
dev = os.getenv("DEV") == "True"

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(False, version="v3")
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# Initialized ScoutMaster API with host: https://api.scoutmaster.nl/v3/
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://api.scoutmaster.nl/v3/

# %%
dev
# Out:
# 'False'

# %%
output_folder = "../data/output/"

# %%
SM_API.output_format = 'df'
project_id = 'fcb3be1a-9357-4280-ba03-de9223f6ef56'
df_layer_types = SM_API.layer_types(project_id)
df_layer_types
# Out:
#                                       id                name  \
# 0   9fa20d5b-e46f-424f-b16f-0200bea8c510            Bijgroei
# 1   24d4a504-8f95-46d7-b199-f79bd1965dd0  Monster locaties 4
# 2   da29cef8-2526-43b0-a3f9-6660e0dc5fb4        Bodemzones 5
# 3   0a0e0317-8dad-4118-8150-f7a29732cd65            Scouting
# 4   502ff6f2-d14a-4e4d-a54c-ba14b1f84387            Stikstof
# 5   a72908c7-8186-4161-9f35-38f3276da130  Monster locaties 5
# 6   13be9851-8133-4b7c-b9ea-1a38683224ba                 DTM
# 7   0685e79a-d5ca-43f8-a634-6068bdbacfab            Biomassa
# 8   d95929cb-b21b-4e40-905e-7b851ea1ec5f         DTM - swiss
# 9   ceb59391-218d-4861-a65a-45663ab4b8e9                 BSI
# 10  2fa79819-30fd-4acd-b6d0-24414a0277a4  Monster locaties 3
# 11  adbd41e6-6442-4ab7-961e-41e46556e118           Prestatie
# 12  38364e64-1142-439c-ad3f-efd45305c9db        Bodemzones 4
# 13  870cb8ea-cdb9-4adb-bb6f-415e0be63abd        Bodemzones 3
#
#               group_name  stacked  \
# 0   Vegetation maps (HD)    False
# 1              soilzones    False
# 2        Soilzoning maps    False
# 3   Vegetation maps (HD)    False
# 4   Vegetation maps (HD)    False
# 5              soilzones    False
# 6         Elevation maps    False
# 7   Vegetation maps (HD)    False
# 8         Elevation maps    False
# 9   Vegetation maps (HD)    False
# 10             soilzones    False
# 11      performance maps    False
# 12       Soilzoning maps    False
# 13       Soilzoning maps    False
#
#                                     preview_image_url  vector bands
# 0   https://bioscope-products.s3.eu-central-1.amaz...   False    []
# 1   https://bioscope-products.s3.eu-central-1.amaz...    True    []
# 2   https://bioscope-products.s3.eu-central-1.amaz...    True    []
# 3   https://bioscope-products.s3.eu-central-1.amaz...    True    []
# 4   https://bioscope-products.s3.eu-central-1.amaz...   False    []
# 5   https://bioscope-products.s3.eu-central-1.amaz...    True    []
# 6   https://bioscope-products.s3.eu-central-1.amaz...   False    []
# 7   https://bioscope-products.s3.eu-central-1.amaz...   False    []
# 8   https://bioscope-products.s3.eu-central-1.amaz...   False    []
# 9   https://bioscope-products.s3.eu-central-1.amaz...   False    []
# 10  https://bioscope-products.s3.eu-central-1.amaz...    True    []
# 11  https://bioscope-products.s3.eu-central-1.amaz...   False    []
# 12  https://bioscope-products.s3.eu-central-1.amaz...    True    []
# 13  https://bioscope-products.s3.eu-central-1.amaz...    True    []

# %%
from IPython.display import Image, HTML, display

def show_layer_previews(df, limit=10):
    rows = []
    for i, row in df.head(limit).iterrows():
        print(row["preview_image_url"])
        rows.append(f"""
        <div style="display:inline-block; margin:10px; text-align:center;">
            <img src="{row['preview_image_url']}" width="150"><br>
            <b>{row['name']}</b><br>
        </div>
        """)
    display(HTML("".join(rows)))

show_layer_previews(df_layer_types)
# Out:
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_AddGrowth.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=599bacf86bfb51c9556336c75b486d11b07073adea9a06f1c3473aa77e16abc9&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ndvi.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=e47837410cda02f6da9875c8474d448e817838d1208c657d0924589bb2b0de57&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Zones5_smooth.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=4422e04afd7eb6ffbf2f15fb1a301cab9c63837732e29a97a97950f7a672afa4&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/scouting.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=8682cd28beb6c680eba72bd3629afcc1e95bfb0988aad85579ca1ed848ccc3e9&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_CI-Red.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=e73eddf9a165b4b7d05aad8784216a08b568418e08811bd5b7c7e751bc431604&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ndvi.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=e47837410cda02f6da9875c8474d448e817838d1208c657d0924589bb2b0de57&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=d4bbf04295e386077a5fad7411479c936576da6f7c9c010afadfb1d1591c42b5&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/PLanet_WDVI.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=1ffe9467fbb00afa254711f96ab7fc8271d78d5c0447c9dae1b4c9096b7a6977&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=d4bbf04295e386077a5fad7411479c936576da6f7c9c010afadfb1d1591c42b5&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_AddGrowth.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=599bacf86bfb51c9556336c75b486d11b07073adea9a06f1c3473aa77e16abc9&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_AddGrowth.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=599bacf86bfb51c9556336c75b486d11b07073adea9a06f1c3473aa77e16abc9&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Bijgroei</b><br>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ndvi.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=e47837410cda02f6da9875c8474d448e817838d1208c657d0924589bb2b0de57&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Monster locaties 4</b><br>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Zones5_smooth.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=4422e04afd7eb6ffbf2f15fb1a301cab9c63837732e29a97a97950f7a672afa4&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Bodemzones 5</b><br>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/scouting.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=8682cd28beb6c680eba72bd3629afcc1e95bfb0988aad85579ca1ed848ccc3e9&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Scouting</b><br>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_CI-Red.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=e73eddf9a165b4b7d05aad8784216a08b568418e08811bd5b7c7e751bc431604&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Stikstof</b><br>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ndvi.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=e47837410cda02f6da9875c8474d448e817838d1208c657d0924589bb2b0de57&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Monster locaties 5</b><br>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=d4bbf04295e386077a5fad7411479c936576da6f7c9c010afadfb1d1591c42b5&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>DTM</b><br>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/PLanet_WDVI.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=1ffe9467fbb00afa254711f96ab7fc8271d78d5c0447c9dae1b4c9096b7a6977&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Biomassa</b><br>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=d4bbf04295e386077a5fad7411479c936576da6f7c9c010afadfb1d1591c42b5&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>DTM - swiss</b><br>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_AddGrowth.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260506%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260506T141747Z&X-Amz-Expires=3600&X-Amz-Signature=599bacf86bfb51c9556336c75b486d11b07073adea9a06f1c3473aa77e16abc9&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>BSI</b><br>
#         </div>
